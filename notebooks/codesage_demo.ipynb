# %% [markdown]
# # CodeSage Demo
#
# This notebook demonstrates how to use CodeSage to analyze code snippets.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from src.analyze import Analyzer

# %%
analyzer = Analyzer()
code_snippet = """
def calc(x, y):
    return x + y
"""
feedback = analyzer.analyze_snippet(code_snippet)
print(feedback)
